# %%
import numpy as np
import chess

def fen_to_board(fen):
    # Parse the FEN string
    parts = fen.split(" ")
    board_part = parts[0]
    isWhite = parts[1] == 'w'

    # Initialize the binary board
    binary_board = np.zeros((768,), dtype=np.float32)
    pieces = {'p': 0, 'r': 1, 'n': 2, 'b': 3, 'q': 4, 'k': 5,
              'P': 6, 'R': 7, 'N': 8, 'B': 9, 'Q': 10, 'K': 11}
    
    # Parse the board part of the FEN string
    rows = board_part.split('/')
    for i, row in enumerate(rows):
        col = 0
        for char in row:
            if char.isdigit():
                # Empty squares
                col += int(char)
            else:
                # Piece
                if isWhite:
                    binary_board[(i*8 + col)*12 + pieces[char]] = 1
                else:
                    binary_board[(63-(i*8 + col))*12 + (pieces[char]+6)%12] = 1
                col += 1

    return binary_board

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim


class SquaredClippedReLU(nn.Module):
    def forward(self, input):
        return F.relu(input.clamp(max=1))**2

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(768, 768)
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(768, 1)

        # Initialize weights and biases
        nn.init.xavier_uniform_(self.fc1.weight)
        nn.init.zeros_(self.fc1.bias)
        nn.init.xavier_uniform_(self.fc2.weight)
        nn.init.zeros_(self.fc2.bias)

    def forward(self, x):
        x = SquaredClippedReLU()(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x


model = Net()

criterion = nn.MSELoss()
optimizer = torch.optim.RMSprop(model.parameters(), lr=0.01)

# %%
print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=768, out_features=768, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=768, out_features=1, bias=True)
# )

# %%
import random
# with open(r'fen_ratingsomate2.txt', 'r') as f:
with open(r'akimbo-2085723380.epd', 'r') as f:
    lines = f.readlines()[:100000]
    
random.shuffle(lines)
fens = [line.split()[0] + " " + line.split()[1] + " " + line.split()[2] for line in lines]
ratings = [(-float(line.split()[-3]) if line.split()[1] == 'b' else float(line.split()[-3]))/1.0 for line in lines] 

binary_boards = []

for fen in fens:
    binary_board = fen_to_board(fen)
    binary_boards.append(binary_board)

binary_boards = np.array(binary_boards)
ratings = np.array(ratings)

# %%
train_size = int(len(binary_boards) * 0.7)
val_size = int(len(binary_boards) * 0.15)

# Separate binary boards and piece amounts
x_binary_train, y_train = binary_boards[:train_size], ratings[:train_size]
x_binary_val, y_val = binary_boards[train_size:train_size + val_size], ratings[train_size:train_size + val_size]
x_binary_test, y_test = binary_boards[train_size + val_size:], ratings[train_size + val_size:]

# %%
# Convert your data to PyTorch tensors
x_binary_train_tensor = torch.tensor(x_binary_train).float()
y_train_tensor = torch.tensor(y_train).float()

x_binary_val_tensor = torch.tensor(x_binary_val).float()
y_val_tensor = torch.tensor(y_val).float()

x_binary_test_tensor = torch.tensor(x_binary_test).float()
y_test_tensor = torch.tensor(y_test).float()


# Ensure your model parameters are of the same data type
model = model.float()


# Create a dataset from your data
train_dataset = TensorDataset(x_binary_train_tensor, y_train_tensor)
val_dataset = TensorDataset(x_binary_val_tensor, y_val_tensor)
test_dataset = TensorDataset(x_binary_test_tensor, y_test_tensor)

# Create a DataLoader with batch size
train_dataloader = DataLoader(train_dataset, batch_size=2, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=2, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=2, shuffle=False)

# %%
from tqdm import tqdm

lambda_l2 = 0.01
train_losses = []
val_losses = []
train_mae = []
val_mae = []

for epoch in range(0):  # loop over the dataset multiple times
    running_loss = 0.0
    running_mae = 0.0
    model.train()  # Set the model to training mode
    progress_bar = tqdm(enumerate(train_dataloader, 0), total=len(train_dataloader))
    for i, data in progress_bar:
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        # print(inputs, labels)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        # print(outputs, labels)

        # L2 regularization
        # l2_reg = torch.tensor(0.).to(inputs.device)
        # for param in model.parameters():
        #     l2_reg += torch.norm(param)
        # loss += lambda_l2 * l2_reg

        loss.backward()
        optimizer.step()

        # calculate MAE
        mae = torch.abs(outputs - labels).mean()

        # print statistics
        running_loss += loss.item()
        running_mae += mae.item()
        progress_bar.set_description(f"Epoch {epoch+1} Loss: {running_loss/(i+1):.4f} MAE: {running_mae/(i+1):.4f}")
    train_losses.append(running_loss / len(train_dataloader))
    train_mae.append(running_mae / len(train_dataloader))

    # Validation phase
    running_loss = 0.0
    running_mae = 0.0
    model.eval()  # Set the model to evaluation mode
    with torch.no_grad():  # No need to track gradients in validation phase
        for i, data in enumerate(val_dataloader, 0):
            inputs, labels = data
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            mae = torch.abs(outputs - labels).mean()
            running_loss += loss.item()
            running_mae += mae.item()
    val_losses.append(running_loss / len(val_dataloader))
    val_mae.append(running_mae / len(val_dataloader))
    print(f"Validation Loss at Epoch {epoch+1}: {running_loss/len(val_dataloader):.4f} MAE: {running_mae/len(val_dataloader):.4f}")

# %%
import matplotlib.pyplot as plt

# Plot training & validation MAE values
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_mae)  
plt.plot(val_mae) 
plt.title('Model Mean Absolute Error')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(train_losses)
plt.plot(val_losses)
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
torch.save(model.state_dict(), 'TrainedModel.pt')

# %%
import matplotlib.pyplot as plt
import numpy as np

x_test_tensor = torch.tensor(x_binary_test[:3000]).float()

# Predict the ratings for the test data
model.eval()
with torch.no_grad():
    y_pred = model(x_test_tensor)

# Convert the predictions to a numpy array
y_pred = y_pred.numpy()

plt.figure(figsize=(10, 6))

# Line x=y for perfect predictions
plt.plot([-1, 1], [-1, 1], color='red', label='Optimal')

# Scatter plot of actual vs predicted values
plt.plot(y_test[:3000], y_pred, marker='o', linestyle='None', markersize=2.0, label='Predictions')

# Least squares fit line
coeff = np.polyfit(y_test[:3000].flatten(), y_pred.flatten(), 1)
fit_line = np.polyval(coeff, y_test[:3000].flatten())
plt.plot(y_test[:3000], fit_line, color='blue', label='Least Squares Fit')

plt.title('Actual vs Predicted Values')
plt.xlabel('Real value')
plt.ylabel('Predicted value')
plt.legend()

plt.show()

# Print the predicted and true ratings for the test data
for i in range(min(len(y_test), 300)):
    print(f"Predicted rating: {y_pred[i]}, True rating: {y_test[i]}")
# Out:
# Predicted rating: [0.01975824], True rating: 199.0
# Predicted rating: [-0.04095542], True rating: 377.0
# Predicted rating: [0.03110398], True rating: -16.0
# Predicted rating: [0.15094014], True rating: 827.0
# Predicted rating: [0.03713353], True rating: -162.0
# Predicted rating: [-0.01566653], True rating: 6.0
# Predicted rating: [-0.0248148], True rating: 386.0
# Predicted rating: [-0.02888671], True rating: -139.0
# Predicted rating: [-0.0064842], True rating: 25.0
# Predicted rating: [0.06526645], True rating: 80.0
# Predicted rating: [-0.02776888], True rating: -679.0
# Predicted rating: [0.02544113], True rating: -564.0
# Predicted rating: [0.00780496], True rating: -15.0
# Predicted rating: [0.06971727], True rating: -211.0
# Predicted rating: [0.02166969], True rating: -18.0
# Predicted rating: [0.03780064], True rating: -65.0
# Predicted rating: [-0.01236357], True rating: 222.0
# Predicted rating: [0.08580779], True rating: 72.0
# Predicted rating: [0.01508473], True rating: -879.0
# Predicted rating: [0.07574554], True rating: -470.0
# Predicted rating: [-0.03171934], True rating: -293.0
# Predicted rating: [0.02630377], True rating: 15.0
# Predicted rating: [0.01029892], True rating: -27.0
# Predicted rating: [0.01482864], True rating: -0.0
# Predicted rating: [0.01397], True rating: 161.0
# Predicted rating: [0.01922008], True rating: -275.0
# Predicted rating: [0.03601837], True rating: 107.0
# Predicted rating: [0.04044506], True rating: 22.0
# Predicted rating: [0.00792925], True rating: 639.0
# Predicted rating: [0.03572072], True rating: 295.0
# Predicted rating: [-0.00047072], True rating: -980.0
# Predicted rating: [-0.0362737], True rating: 223.0
# Predicted rating: [0.04543561], True rating: -254.0
# Predicted rating: [0.01578239], True rating: -305.0
# Predicted rating: [0.0422539], True rating: -273.0
# Predicted rating: [-0.0436076], True rating: -851.0
# Predicted rating: [-0.05663665], True rating: -583.0
# Predicted rating: [0.08769703], True rating: 93.0
# Predicted rating: [0.04337025], True rating: 659.0
# Predicted rating: [-0.0105683], True rating: -483.0
# Predicted rating: [0.00906446], True rating: -905.0
# Predicted rating: [0.01630297], True rating: -935.0
# Predicted rating: [0.03836859], True rating: 345.0
# Predicted rating: [0.05179209], True rating: 60.0
# Predicted rating: [-0.00238051], True rating: 24.0
# Predicted rating: [0.011355], True rating: -225.0
# Predicted rating: [0.0048189], True rating: 401.0
# Predicted rating: [-0.02830899], True rating: 568.0
# Predicted rating: [0.01551903], True rating: -346.0
# Predicted rating: [0.0142696], True rating: -666.0
# Predicted rating: [0.08847295], True rating: 74.0
# Predicted rating: [0.05439036], True rating: 18.0
# Predicted rating: [0.04094237], True rating: -383.0
# Predicted rating: [-0.04050387], True rating: -37.0
# Predicted rating: [0.07544007], True rating: -188.0
# Predicted rating: [-0.0051815], True rating: 43.0
# Predicted rating: [0.05262143], True rating: 374.0
# Predicted rating: [0.04193938], True rating: -173.0
# Predicted rating: [0.00123499], True rating: 212.0
# Predicted rating: [-0.03757079], True rating: -270.0
# Predicted rating: [0.03628188], True rating: 38.0
# Predicted rating: [0.0332084], True rating: -139.0
# Predicted rating: [0.02293832], True rating: -551.0
# Predicted rating: [0.0094531], True rating: -884.0
# Predicted rating: [0.13887039], True rating: -252.0
# Predicted rating: [0.00416141], True rating: 653.0
# Predicted rating: [-0.00581351], True rating: -204.0
# Predicted rating: [0.06024401], True rating: -302.0
# Predicted rating: [0.03324938], True rating: 284.0
# Predicted rating: [-0.04009572], True rating: -97.0
# Predicted rating: [0.0263276], True rating: -66.0
# Predicted rating: [0.01534701], True rating: -116.0
# Predicted rating: [0.06514274], True rating: 657.0
# Predicted rating: [0.0047673], True rating: 66.0
# Predicted rating: [0.05163611], True rating: -49.0
# Predicted rating: [0.07675551], True rating: 464.0
# Predicted rating: [0.03776881], True rating: 669.0
# Predicted rating: [0.10850579], True rating: 682.0
# Predicted rating: [0.06836529], True rating: 33.0
# Predicted rating: [0.03714576], True rating: -811.0
# Predicted rating: [0.03523857], True rating: -849.0
# Predicted rating: [0.08944403], True rating: 664.0
# Predicted rating: [-0.00590116], True rating: -405.0
# Predicted rating: [0.00992025], True rating: -302.0
# Predicted rating: [0.01106227], True rating: -49.0
# Predicted rating: [0.01981208], True rating: 410.0
# Predicted rating: [-0.01809218], True rating: 98.0
# Predicted rating: [0.00823765], True rating: -501.0
# Predicted rating: [0.03410576], True rating: -420.0
# Predicted rating: [0.01601589], True rating: 103.0
# Predicted rating: [0.0586649], True rating: -641.0
# Predicted rating: [0.02886132], True rating: -451.0
# Predicted rating: [0.03335005], True rating: -607.0
# Predicted rating: [0.0280025], True rating: 141.0
# Predicted rating: [0.00875797], True rating: 66.0
# Predicted rating: [0.08942141], True rating: 79.0
# Predicted rating: [-0.01020444], True rating: -858.0
# Predicted rating: [0.05876322], True rating: 275.0
# Predicted rating: [0.0480671], True rating: -413.0
# Predicted rating: [0.09475923], True rating: -10.0
# Predicted rating: [0.01032291], True rating: -328.0
# Predicted rating: [-0.02029048], True rating: 21.0
# Predicted rating: [-0.00385154], True rating: -0.0
# Predicted rating: [-0.02454939], True rating: -135.0
# Predicted rating: [0.09135712], True rating: -246.0
# Predicted rating: [-0.00052236], True rating: -225.0
# Predicted rating: [-0.029059], True rating: 97.0
# Predicted rating: [-0.0072112], True rating: -449.0
# Predicted rating: [-0.04149425], True rating: 173.0
# Predicted rating: [0.03703558], True rating: -419.0
# Predicted rating: [0.04980604], True rating: 285.0
# Predicted rating: [0.05711394], True rating: -385.0
# Predicted rating: [0.09928012], True rating: -70.0
# Predicted rating: [-0.02386067], True rating: 88.0
# Predicted rating: [-0.09116362], True rating: 579.0
# Predicted rating: [0.10090925], True rating: -216.0
# Predicted rating: [-0.07087653], True rating: -143.0
# Predicted rating: [0.00347875], True rating: -65.0
# Predicted rating: [-0.01522584], True rating: 77.0
# Predicted rating: [-0.05828998], True rating: 213.0
# Predicted rating: [0.06382164], True rating: 105.0
# Predicted rating: [0.06178394], True rating: 31.0
# Predicted rating: [-0.01925423], True rating: 179.0
# Predicted rating: [0.01214042], True rating: 144.0
# Predicted rating: [0.05896561], True rating: 290.0
# Predicted rating: [0.01336109], True rating: 126.0
# Predicted rating: [-0.01986169], True rating: -25.0
# Predicted rating: [0.02081109], True rating: -105.0
# Predicted rating: [0.01767774], True rating: 610.0
# Predicted rating: [0.00367182], True rating: 0.0
# Predicted rating: [0.00675715], True rating: 785.0
# Predicted rating: [0.0099546], True rating: -745.0
# Predicted rating: [0.02130301], True rating: 523.0
# Predicted rating: [-0.00155568], True rating: -334.0
# Predicted rating: [0.01474768], True rating: -217.0
# Predicted rating: [-0.02571002], True rating: 171.0
# Predicted rating: [0.00478023], True rating: -21.0
# Predicted rating: [-0.01469386], True rating: -109.0
# Predicted rating: [-0.02478847], True rating: 232.0
# Predicted rating: [0.01035464], True rating: -525.0
# Predicted rating: [-0.02465325], True rating: -254.0
# Predicted rating: [-0.00125774], True rating: 598.0
# Predicted rating: [0.01103228], True rating: -137.0
# Predicted rating: [0.0073213], True rating: 23.0
# Predicted rating: [0.04873101], True rating: -148.0
# Predicted rating: [-0.02118929], True rating: 363.0
# Predicted rating: [0.01804311], True rating: -97.0
# Predicted rating: [0.03126517], True rating: 502.0
# Predicted rating: [0.09193249], True rating: -950.0
# Predicted rating: [-0.01743132], True rating: -25.0
# Predicted rating: [0.08543134], True rating: -171.0
# Predicted rating: [0.13464114], True rating: -188.0
# Predicted rating: [0.08655053], True rating: -449.0
# Predicted rating: [0.06204151], True rating: -489.0
# Predicted rating: [0.00395887], True rating: -237.0
# Predicted rating: [0.01820449], True rating: -431.0
# Predicted rating: [0.03376489], True rating: 55.0
# Predicted rating: [0.03014146], True rating: -699.0
# Predicted rating: [0.02557383], True rating: -758.0
# Predicted rating: [0.04173931], True rating: -14.0
# Predicted rating: [-0.00398261], True rating: -538.0
# Predicted rating: [0.02966623], True rating: -240.0
# Predicted rating: [0.03342335], True rating: 111.0
# Predicted rating: [0.00844329], True rating: -700.0
# Predicted rating: [0.0202735], True rating: -313.0
# Predicted rating: [0.0855609], True rating: 36.0
# Predicted rating: [0.01694663], True rating: -135.0
# Predicted rating: [0.0394479], True rating: 383.0
# Predicted rating: [0.00606577], True rating: 547.0
# Predicted rating: [0.06617061], True rating: 178.0
# Predicted rating: [-0.01552628], True rating: 550.0
# Predicted rating: [-0.00813739], True rating: 247.0
# Predicted rating: [0.03622295], True rating: 238.0
# Predicted rating: [0.05529192], True rating: -190.0
# Predicted rating: [-0.00960814], True rating: -207.0
# Predicted rating: [0.00811128], True rating: 148.0
# Predicted rating: [0.00338637], True rating: 311.0
# Predicted rating: [0.14745517], True rating: -265.0
# Predicted rating: [-0.01142371], True rating: 459.0
# Predicted rating: [0.01588885], True rating: -0.0
# Predicted rating: [0.02297868], True rating: 706.0
# Predicted rating: [-0.01511251], True rating: 196.0
# Predicted rating: [0.01049405], True rating: 185.0
# Predicted rating: [-0.07204491], True rating: -74.0
# Predicted rating: [0.01119936], True rating: -830.0
# Predicted rating: [0.02910485], True rating: 29.0
# Predicted rating: [0.02232797], True rating: 572.0
# Predicted rating: [0.07003371], True rating: 88.0
# Predicted rating: [-0.06100398], True rating: -290.0
# Predicted rating: [0.09893026], True rating: 170.0
# Predicted rating: [0.10146151], True rating: 55.0
# Predicted rating: [-0.01142471], True rating: -38.0
# Predicted rating: [0.05279701], True rating: 90.0
# Predicted rating: [0.02173628], True rating: 187.0
# Predicted rating: [0.01938615], True rating: 517.0
# Predicted rating: [0.03977533], True rating: -440.0
# Predicted rating: [0.0339966], True rating: 269.0
# Predicted rating: [0.01165821], True rating: -117.0
# Predicted rating: [0.12978268], True rating: 180.0
# Predicted rating: [0.00676783], True rating: -331.0
# Predicted rating: [0.0044873], True rating: -0.0
# Predicted rating: [0.01141375], True rating: -905.0
# Predicted rating: [0.09239301], True rating: -110.0
# Predicted rating: [-0.02187244], True rating: 0.0
# Predicted rating: [0.03632805], True rating: 386.0
# Predicted rating: [0.01139716], True rating: 119.0
# Predicted rating: [0.00167135], True rating: -6.0
# Predicted rating: [-0.0209218], True rating: -523.0
# Predicted rating: [0.01620597], True rating: 44.0
# Predicted rating: [0.03294573], True rating: 432.0
# Predicted rating: [-0.03010195], True rating: 59.0
# Predicted rating: [0.08826745], True rating: -38.0
# Predicted rating: [0.01962317], True rating: -0.0
# Predicted rating: [0.10344011], True rating: -64.0
# Predicted rating: [0.02605276], True rating: 2.0
# Predicted rating: [0.00566956], True rating: -743.0
# Predicted rating: [0.00882254], True rating: -855.0
# Predicted rating: [0.03979567], True rating: 496.0
# Predicted rating: [-0.01814676], True rating: 549.0
# Predicted rating: [-0.0451675], True rating: 426.0
# Predicted rating: [0.05892721], True rating: -39.0
# Predicted rating: [-0.05524734], True rating: -22.0
# Predicted rating: [0.02924074], True rating: -0.0
# Predicted rating: [0.02068669], True rating: 893.0
# Predicted rating: [0.03493019], True rating: -769.0
# Predicted rating: [0.00175914], True rating: 442.0
# Predicted rating: [0.0174791], True rating: 153.0
# Predicted rating: [0.07128151], True rating: 149.0
# Predicted rating: [0.03011869], True rating: -148.0
# Predicted rating: [0.06727722], True rating: -159.0
# Predicted rating: [0.00403877], True rating: -624.0
# Predicted rating: [0.13256855], True rating: -47.0
# Predicted rating: [0.03667617], True rating: -100.0
# Predicted rating: [0.01783864], True rating: 475.0
# Predicted rating: [0.03752125], True rating: 484.0
# Predicted rating: [0.01329593], True rating: 774.0
# Predicted rating: [0.0248232], True rating: 25.0
# Predicted rating: [0.00909962], True rating: 0.0
# Predicted rating: [0.00797024], True rating: 780.0
# Predicted rating: [0.07612611], True rating: 139.0
# Predicted rating: [0.07612294], True rating: 244.0
# Predicted rating: [0.0141426], True rating: 119.0
# Predicted rating: [0.033434], True rating: -434.0
# Predicted rating: [0.01136788], True rating: -216.0
# Predicted rating: [-0.07488951], True rating: 290.0
# Predicted rating: [0.01195806], True rating: 37.0
# Predicted rating: [0.00148118], True rating: -29.0
# Predicted rating: [0.061402], True rating: -170.0
# Predicted rating: [0.02599788], True rating: -203.0
# Predicted rating: [0.06153038], True rating: 268.0
# Predicted rating: [0.06212109], True rating: 813.0
# Predicted rating: [0.00931496], True rating: -275.0
# Predicted rating: [0.00402759], True rating: 201.0
# Predicted rating: [-0.00780202], True rating: 250.0
# Predicted rating: [-0.0148294], True rating: 506.0
# Predicted rating: [0.02487317], True rating: 802.0
# Predicted rating: [0.01294451], True rating: 17.0
# Predicted rating: [0.02230111], True rating: -236.0
# Predicted rating: [-0.03975937], True rating: -330.0
# Predicted rating: [0.06992037], True rating: -14.0
# Predicted rating: [-0.0587044], True rating: 669.0
# Predicted rating: [0.08355774], True rating: -414.0
# Predicted rating: [0.08625685], True rating: -384.0
# Predicted rating: [-0.02331471], True rating: 231.0
# Predicted rating: [-0.02239106], True rating: 675.0
# Predicted rating: [0.00331562], True rating: -215.0
# Predicted rating: [0.02841424], True rating: -0.0
# Predicted rating: [0.00882526], True rating: -513.0
# Predicted rating: [0.00963887], True rating: 50.0
# Predicted rating: [0.05906919], True rating: 495.0
# Predicted rating: [-0.02563228], True rating: -209.0
# Predicted rating: [0.00267963], True rating: -127.0
# Predicted rating: [0.14417641], True rating: -5.0
# Predicted rating: [-0.01476367], True rating: 35.0
# Predicted rating: [-0.01800301], True rating: 13.0
# Predicted rating: [0.02735623], True rating: -723.0
# Predicted rating: [0.00370003], True rating: 482.0
# Predicted rating: [0.01848318], True rating: 687.0
# Predicted rating: [0.01225974], True rating: 0.0
# Predicted rating: [-0.0087284], True rating: 482.0
# Predicted rating: [0.01331799], True rating: 220.0
# Predicted rating: [0.00639463], True rating: 680.0
# Predicted rating: [0.07868975], True rating: -101.0
# Predicted rating: [-0.01643641], True rating: 361.0
# Predicted rating: [0.051022], True rating: 187.0
# Predicted rating: [0.07440944], True rating: -513.0
# Predicted rating: [0.02435324], True rating: 918.0
# Predicted rating: [0.03589199], True rating: -778.0
# Predicted rating: [-0.01102196], True rating: -48.0
# Predicted rating: [0.00183919], True rating: 82.0
# Predicted rating: [0.04546998], True rating: -52.0
# Predicted rating: [0.05271608], True rating: 920.0
# Predicted rating: [0.00035298], True rating: 0.0
# Predicted rating: [0.0219111], True rating: 125.0
# Predicted rating: [-0.01599755], True rating: 280.0
# Predicted rating: [0.06107685], True rating: 178.0
# Predicted rating: [0.0072306], True rating: -175.0
# Predicted rating: [0.04733656], True rating: -87.0
# Predicted rating: [0.00757944], True rating: 188.0
# Predicted rating: [-0.0160214], True rating: 127.0
